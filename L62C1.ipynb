# %%
import pandas as pd

# %%
fuel = pd.read_csv('./data/fuel.csv',low_memory=False,index_col='Make')

# %%
fuel.head()
# Out:
#             Vehicle ID  Year               Model                        Class  \
# Make
# Alfa Romeo       26587  1984           GT V6 2.5             Minicompact Cars
# Alfa Romeo       27705  1984           GT V6 2.5             Minicompact Cars
# Alfa Romeo       26561  1984  Spider Veloce 2000                  Two Seaters
# Alfa Romeo       27681  1984  Spider Veloce 2000                  Two Seaters
# AM General       27550  1984   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#                     Drive       Transmission Transmission Descriptor  \
# Make
# Alfa Romeo            NaN     Manual 5-Speed                     NaN
# Alfa Romeo            NaN     Manual 5-Speed                     NaN
# Alfa Romeo            NaN     Manual 5-Speed                     NaN
# Alfa Romeo            NaN     Manual 5-Speed                     NaN
# AM General  2-Wheel Drive  Automatic 3-Speed                     NaN
#
# ...

# %%
pd.options.display.max_columns=500

# %%
fuel.head(10)
# Out:
#                              Vehicle ID  Year               Model  \
# Make
# Alfa Romeo                        26587  1984           GT V6 2.5
# Alfa Romeo                        27705  1984           GT V6 2.5
# Alfa Romeo                        26561  1984  Spider Veloce 2000
# Alfa Romeo                        27681  1984  Spider Veloce 2000
# AM General                        27550  1984   DJ Po Vehicle 2WD
# AM General                        28426  1984   DJ Po Vehicle 2WD
# AM General                        27549  1984    FJ8c Post Office
# AM General                        28425  1984    FJ8c Post Office
# American Motors Corporation       27593  1984           Eagle 4WD
# American Motors Corporation       28455  1984           Eagle 4WD
#
#                                                    Class  \
# Make
# Alfa Romeo                              Minicompact Cars
# Alfa Romeo                              Minicompact Cars
# ...

# %%
fuel.tail()
# Out:
#             Vehicle ID  Year             Model         Class  \
# Make
# Mitsubishi       32060  2012            Lancer  Compact Cars
# Mitsubishi       32063  2012        Lancer AWD  Compact Cars
# Mitsubishi       32065  2012  Lancer Evolution  Compact Cars
# Mitsubishi       32064  2012  Lancer Evolution  Compact Cars
# Mitsubish        32106  2012               NaN           NaN
#
#                         Drive    Transmission Transmission Descriptor  \
# Make
# Mitsubishi  Front-Wheel Drive  Manual 5-Speed                     NaN
# Mitsubishi    All-Wheel Drive     Auto(AV-S6)                     NaN
# Mitsubishi    All-Wheel Drive       Auto(AM6)                     NaN
# Mitsubishi    All-Wheel Drive  Manual 5-Speed                     NaN
# Mitsubish                 NaN             NaN                     NaN
#
#             Engine Index Engine Descriptor  Engine Cylinders  \
# Make
# Mitsubishi         113.0               NaN               4.0
# ...

# %%
fuel = pd.read_csv('./data/fuel.csv',usecols=['Vehicle ID', 'Year', 'Make', 'Model','Class','Fuel Type','Combined MPG (FT1)'])

# %%
fuel.head()
# Out:
#    Vehicle ID  Year        Make               Model  \
# 0       26587  1984  Alfa Romeo           GT V6 2.5
# 1       27705  1984  Alfa Romeo           GT V6 2.5
# 2       26561  1984  Alfa Romeo  Spider Veloce 2000
# 3       27681  1984  Alfa Romeo  Spider Veloce 2000
# 4       27550  1984  AM General   DJ Po Vehicle 2WD
#
#                          Class Fuel Type  Combined MPG (FT1)
# 0             Minicompact Cars   Regular                20.0
# 1             Minicompact Cars   Regular                20.0
# 2                  Two Seaters   Regular                21.0
# 3                  Two Seaters   Regular                21.0
# 4  Special Purpose Vehicle 2WD   Regular                17.0
